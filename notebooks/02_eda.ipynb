# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# ## EDA

# %%
#Correlation Matrix
sns.heatmap(diabetes_imputed.corr(), annot=True)
plt.show()

# %% [markdown]
# Similarly to the notebook from the previous sprint:
#
# Glucose still remains to be the highest correlated with the outcome variable meaning the higher the glucose, more likely someone will get diabetes.
#
# Some independent variables are strongly correlated with eachother which may not be ideal, however medically speaking this is pretty accurate.
#
# For example, BMI and SkinThickness have a correlation of 0.71 meaning as your skin becomes more thick, the higher your body mass will be.
#
# Although Blood Pressure and Diabetes Pedigree Function (DPF) are still weakly correlated with outcome variable, DPF still has the weakest reltionship with other variables.

# %%
#Plotting histograms to see how they all are distributed by first defining variables
X = diabetes_imputed[diabetes_imputed.columns[:-1]]
y = diabetes_imputed['Outcome']

# %%
#Plotting histograms
for col in X.columns:
  plt.hist(X[col])
  plt.xlabel(col)
  plt.show()

# %% [markdown]
# Age, DPF and Pregnancies are exponentially distributed while other variables are normally distributed.

# %%
#Plotting boxplots
for col in X.columns:
  sns.boxplot(X[col])
  plt.xlabel(col)
  plt.show()

# %% [markdown]
# Similary to the previous sprint, every variable except Glucose has outliers which would be handled while building models.
